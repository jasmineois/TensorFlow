# %%
import cv2
from os import path

def faceCut(path, dir, index):
    # 定数
    FACE_COLOR = (255, 0, 0)
    IMAGE_SIZE = 112

    # cascadeファイルをロードする
    cascades_dir = "../python/haarcascades/haarcascade_frontalface_alt2.xml"
    cascade_f = cv2.CascadeClassifier(cascades_dir)
    
    # 画像を読み込む
    img = cv2.imread('../image/original' + '/' + dir + '/' + path)

    # グレイスケールに変換
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # 検出して四角で囲む
    face = cascade_f.detectMultiScale(gray)
    for (x, y, w, h) in face:
        cv2.rectangle(img, (x, y), (x + w, y + h), FACE_COLOR, 2)

    # 切り抜き出来なかったらreturn
    if len(face) == 0 : return "---"
    
    # 切り抜き
    face = img[y:y+h, x:x+h]
    face = cv2.resize(face, (IMAGE_SIZE, IMAGE_SIZE))

    #認識結果の保存
    root, ext = os.path.splitext(path)
    cv2.imwrite('../image/cut/' + dir + str(index) + ext, face)
    
    return ('../image/cut/' + dir + str(index) + ext)

# %%
import cv2
from os import path

def faceMove(path, dir, index):
    
    # 画像を読み込む
    face = cv2.imread('../image/original' + '/' + dir + '/' + path)
    
     #認識結果の保存
    root, ext = os.path.splitext(path)
    cv2.imwrite('../image/cut/' + dir + str(index) + ext, face)
    
    return ('../image/cut/' + dir + str(index) + ext)

# %%
import sys
import os

original_path = '../image/original'

if __name__ == '__main__':

    # テストデータ書き出し用
    train = open('../data/train.txt', 'w')
    test = open('../data/test.txt', 'w')

    # パスの抜き出し
    files = os.listdir(original_path)
    files_dir = [f for f in files if os.path.isdir(os.path.join(original_path, f))]
    print(files_dir)

    index = 0
    for n, dir in enumerate(files_dir):
        print('---------------------------')
        dir_path = original_path + '/' + dir
        files = os.listdir(dir_path)
        for i, file in  enumerate(files):
            print(i, dir, file)
            file_path = dir_path + '/' + file
            #txt = faceCut(file, dir, i)
            txt = faceMove(file, dir, i)

            # 画像が抽出できなかったら破棄
            if txt == "---" : 
                os.rename(
                    '../image/original' + '/' + dir + '/' + file,
                    '../image/original' + '/' + 'discard_' + file
                )
                continue

            # テキストに書き出し
            if i <= 0:
                test.write(txt + ' ' + str(n) + '\n')
            else:
                train.write(txt + ' ' + str(n) + '\n')

    train.close()
    test.close()

    print('---------------------------')
    print('complete!')
# Out:
# ['hara', 'nothara', 'nothuman']
# ---------------------------
# (0, 'hara', '0000000209_0.jpg')
# (1, 'hara', '0000000211_0.jpg')
# (2, 'hara', '0000000212_0.jpg')
# (3, 'hara', '0000000222_0.jpg')
# (4, 'hara', '0000000223_0.jpg')
# (5, 'hara', '0000000228_0.jpg')
# (6, 'hara', '0000000236_0.jpg')
# (7, 'hara', '0000000237_0.jpg')
# (8, 'hara', '0000000238_0.jpg')
# (9, 'hara', '0000000239_0.jpg')
# (10, 'hara', '0000000240_0.jpg')
# (11, 'hara', '0000000241_0.jpg')
# (12, 'hara', '0000000242_0.jpg')
# (13, 'hara', '0000000243_0.jpg')
# (14, 'hara', '0000000244_0.jpg')
# (15, 'hara', '0000000245_0.jpg')
# (16, 'hara', '0000000246_0.jpg')
# (17, 'hara', '0000000247_0.jpg')
# (18, 'hara', '0000000248_0.jpg')
# (19, 'hara', '0000000249_0.jpg')
# (20, 'hara', '0000000250_0.jpg')
# (21, 'hara', '0000000251_0.jpg')
# (22, 'hara', '0000000252_0.jpg')
# (23, 'hara', '0000000253_0.jpg')
# (24, 'hara', '0000000254_0.jpg')
# (25, 'hara', '0000000255_0.jpg')
# (26, 'hara', '0000000256_0.jpg')
# (27, 'hara', '0000000257_0.jpg')
# (28, 'hara', '0000000258_0.jpg')
# (29, 'hara', '0000000259_0.jpg')
# (30, 'hara', '0000000260_0.jpg')
# (31, 'hara', '0000000261_0.jpg')
# (32, 'hara', '0000000262_0.jpg')
# (33, 'hara', '0000000263_0.jpg')
# (34, 'hara', '0000000264_0.jpg')
# (35, 'hara', '0000000265_0.jpg')
# (36, 'hara', '0000000266_0.jpg')
# (37, 'hara', '0000000267_0.jpg')
# (38, 'hara', '0000000268_0.jpg')
# (39, 'hara', '0000000269_0.jpg')
# (40, 'hara', '0000000270_0.jpg')
# (41, 'hara', '0000000271_0.jpg')
# (42, 'hara', '0000000272_0.jpg')
# (43, 'hara', '0000000273_0.jpg')
# (44, 'hara', '0000000274_0.jpg')
# (45, 'hara', '0000000275_0.jpg')
# (46, 'hara', '0000000276_0.jpg')
# (47, 'hara', '0000000277_0.jpg')
# (48, 'hara', '0000000278_0.jpg')
# (49, 'hara', '0000000279_0.jpg')
# (50, 'hara', '0000000280_0.jpg')
# (51, 'hara', '0000000281_0.jpg')
# (52, 'hara', '0000000282_0.jpg')
# (53, 'hara', '0000000283_0.jpg')
# (54, 'hara', '0000000284_0.jpg')
# (55, 'hara', '0000000285_0.jpg')
# (56, 'hara', '0000000286_0.jpg')
# (57, 'hara', '0000000287_0.jpg')
# (58, 'hara', '0000000288_0.jpg')
# (59, 'hara', '0000000289_0.jpg')
# (60, 'hara', '0000000290_0.jpg')
# (61, 'hara', '0000000291_0.jpg')
# (62, 'hara', '0000000292_0.jpg')
# (63, 'hara', '0000000293_0.jpg')
# (64, 'hara', '0000000294_0.jpg')
# (65, 'hara', '0000000295_0.jpg')
# (66, 'hara', '0000000296_0.jpg')
# (67, 'hara', '0000000297_0.jpg')
# (68, 'hara', '0000000298_0.jpg')
# (69, 'hara', '0000000299_0.jpg')
# (70, 'hara', '0000000300_0.jpg')
# (71, 'hara', '0000000301_0.jpg')
# (72, 'hara', '0000000302_0.jpg')
# (73, 'hara', '0000000303_0.jpg')
# (74, 'hara', '0000000304_0.jpg')
# (75, 'hara', '0000000305_0.jpg')
# (76, 'hara', '0000000306_0.jpg')
# (77, 'hara', '0000000307_0.jpg')
# (78, 'hara', '0000000308_0.jpg')
# (79, 'hara', '0000000309_0.jpg')
# (80, 'hara', '0000000310_0.jpg')
# (81, 'hara', '0000000311_0.jpg')
# (82, 'hara', '0000000312_0.jpg')
# (83, 'hara', '0000000313_0.jpg')
# (84, 'hara', '0000000314_0.jpg')
# (85, 'hara', '0000000315_0.jpg')
# (86, 'hara', '0000000316_0.jpg')
# (87, 'hara', '0000000317_0.jpg')
# (88, 'hara', '0000000318_0.jpg')
# (89, 'hara', '0000000319_0.jpg')
# (90, 'hara', '0000000320_0.jpg')
# (91, 'hara', '0000000321_0.jpg')
# (92, 'hara', '0000000322_0.jpg')
# (93, 'hara', '0000000323_0.jpg')
# (94, 'hara', '0000000324_0.jpg')
# (95, 'hara', '0000000325_0.jpg')
# (96, 'hara', '0000000326_0.jpg')
# (97, 'hara', '0000000327_0.jpg')
# (98, 'hara', '0000000328_0.jpg')
# (99, 'hara', '0000000329_0.jpg')
# (100, 'hara', '0000000330_0.jpg')
# (101, 'hara', '0000000331_0.jpg')
# (102, 'hara', '0000000332_0.jpg')
# (103, 'hara', '0000000333_0.jpg')
# (104, 'hara', '0000000334_0.jpg')
# (105, 'hara', '0000000335_0.jpg')
# (106, 'hara', '0000000336_0.jpg')
# (107, 'hara', '0000000337_0.jpg')
# (108, 'hara', '0000000339_0.jpg')
# (109, 'hara', '0000000345_0.jpg')
# (110, 'hara', '0000000346_0.jpg')
# (111, 'hara', '0000000347_0.jpg')
# (112, 'hara', '0000000348_0.jpg')
# (113, 'hara', '0000000349_0.jpg')
# (114, 'hara', '0000000350_0.jpg')
# (115, 'hara', '0000000351_0.jpg')
# (116, 'hara', '0000000352_0.jpg')
# (117, 'hara', '0000000353_0.jpg')
# (118, 'hara', '0000000354_0.jpg')
# (119, 'hara', '0000000355_0.jpg')
# (120, 'hara', '0000000356_0.jpg')
# (121, 'hara', '0000000357_0.jpg')
# (122, 'hara', '0000000358_0.jpg')
# (123, 'hara', '0000000359_0.jpg')
# (124, 'hara', '0000000360_0.jpg')
# (125, 'hara', '0000000361_0.jpg')
# (126, 'hara', '0000000362_0.jpg')
# (127, 'hara', '0000000363_0.jpg')
# (128, 'hara', '0000000364_0.jpg')
# (129, 'hara', '0000000365_0.jpg')
# (130, 'hara', '0000000366_0.jpg')
# (131, 'hara', '0000000367_0.jpg')
# (132, 'hara', '0000000368_0.jpg')
# (133, 'hara', '0000000369_0.jpg')
# (134, 'hara', '0000000370_0.jpg')
# (135, 'hara', '0000000371_0.jpg')
# (136, 'hara', '0000000372_0.jpg')
# (137, 'hara', '0000000373_0.jpg')
# (138, 'hara', '0000000374_0.jpg')
# (139, 'hara', '0000000375_0.jpg')
# (140, 'hara', '0000000376_0.jpg')
# (141, 'hara', '0000000377_0.jpg')
# (142, 'hara', '0000000378_0.jpg')
# (143, 'hara', '0000000379_0.jpg')
# (144, 'hara', '0000000380_0.jpg')
# (145, 'hara', '0000000381_0.jpg')
# (146, 'hara', '0000000382_0.jpg')
# (147, 'hara', '0000000383_0.jpg')
# (148, 'hara', '0000000384_0.jpg')
# (149, 'hara', '0000000385_0.jpg')
# (150, 'hara', '0000000386_0.jpg')
# (151, 'hara', '0000000387_0.jpg')
# (152, 'hara', '0000000388_0.jpg')
# (153, 'hara', '0000000389_0.jpg')
# (154, 'hara', '0000000390_0.jpg')
# (155, 'hara', '0000000391_0.jpg')
# (156, 'hara', '0000000392_0.jpg')
# (157, 'hara', '0000000393_0.jpg')
# (158, 'hara', '0000000394_0.jpg')
# (159, 'hara', '0000000395_0.jpg')
# (160, 'hara', '0000000396_0.jpg')
# (161, 'hara', '0000000397_0.jpg')
# (162, 'hara', '0000000398_0.jpg')
# (163, 'hara', '0000000399_0.jpg')
# (164, 'hara', '0000000400_0.jpg')
# (165, 'hara', '0000000401_0.jpg')
# (166, 'hara', '0000000402_0.jpg')
# (167, 'hara', '0000000403_0.jpg')
# (168, 'hara', '0000000404_0.jpg')
# (169, 'hara', '0000000405_0.jpg')
# (170, 'hara', '0000000406_0.jpg')
# (171, 'hara', '0000000407_0.jpg')
# (172, 'hara', '0000000408_0.jpg')
# (173, 'hara', '0000000409_0.jpg')
# (174, 'hara', '0000000410_0.jpg')
# (175, 'hara', '0000000411_0.jpg')
# (176, 'hara', '0000000412_0.jpg')
# (177, 'hara', '0000000413_0.jpg')
# (178, 'hara', '0000000414_0.jpg')
# (179, 'hara', '0000000415_0.jpg')
# (180, 'hara', '0000000416_0.jpg')
# (181, 'hara', '0000000417_0.jpg')
# (182, 'hara', '0000000418_0.jpg')
# (183, 'hara', '0000000419_0.jpg')
# (184, 'hara', '0000000420_0.jpg')
# (185, 'hara', '0000000421_0.jpg')
# (186, 'hara', '0000000422_0.jpg')
# (187, 'hara', '0000000423_0.jpg')
# (188, 'hara', '0000000424_0.jpg')
# (189, 'hara', '0000000425_0.jpg')
# (190, 'hara', '0000000426_0.jpg')
# (191, 'hara', '0000000427_0.jpg')
# (192, 'hara', '0000000428_0.jpg')
# (193, 'hara', '0000000429_0.jpg')
# (194, 'hara', '0000000430_0.jpg')
# (195, 'hara', '0000000431_0.jpg')
# (196, 'hara', '0000000432_0.jpg')
# (197, 'hara', '0000000433_0.jpg')
# (198, 'hara', '0000000434_0.jpg')
# (199, 'hara', '0000000435_0.jpg')
# (200, 'hara', '0000000436_0.jpg')
# (201, 'hara', '0000000437_0.jpg')
# (202, 'hara', '0000000438_0.jpg')
# (203, 'hara', '0000000439_0.jpg')
# (204, 'hara', '0000000440_0.jpg')
# (205, 'hara', '0000000441_0.jpg')
# (206, 'hara', '0000000442_0.jpg')
# (207, 'hara', '0000000443_0.jpg')
# (208, 'hara', '0000000444_0.jpg')
# (209, 'hara', '0000000445_0.jpg')
# (210, 'hara', '0000000446_0.jpg')
# (211, 'hara', '0000000447_0.jpg')
# (212, 'hara', '0000000448_0.jpg')
# (213, 'hara', '0000000449_0.jpg')
# (214, 'hara', '0000000450_0.jpg')
# (215, 'hara', '0000000451_0.jpg')
# (216, 'hara', '0000000452_0.jpg')
# (217, 'hara', '0000000453_0.jpg')
# (218, 'hara', '0000000454_0.jpg')
# (219, 'hara', '0000000455_0.jpg')
# (220, 'hara', '0000000456_0.jpg')
# (221, 'hara', '0000000457_0.jpg')
# (222, 'hara', '0000000458_0.jpg')
# (223, 'hara', '0000000459_0.jpg')
# (224, 'hara', '0000000460_0.jpg')
# (225, 'hara', '0000000461_0.jpg')
# (226, 'hara', '0000000462_0.jpg')
# (227, 'hara', '0000000463_0.jpg')
# (228, 'hara', '0000000464_0.jpg')
# (229, 'hara', '0000000465_0.jpg')
# (230, 'hara', '0000000466_0.jpg')
# (231, 'hara', '0000000467_0.jpg')
# (232, 'hara', '0000000468_0.jpg')
# (233, 'hara', '0000000469_0.jpg')
# (234, 'hara', '0000000470_0.jpg')
# (235, 'hara', '0000000471_0.jpg')
# (236, 'hara', '0000000472_0.jpg')
# (237, 'hara', '0000000473_0.jpg')
# (238, 'hara', '0000000474_0.jpg')
# (239, 'hara', '0000000475_0.jpg')
# (240, 'hara', '0000000476_0.jpg')
# (241, 'hara', '0000000477_0.jpg')
# (242, 'hara', '0000000478_0.jpg')
# (243, 'hara', '0000000479_0.jpg')
# (244, 'hara', '0000000480_0.jpg')
# (245, 'hara', '0000000481_0.jpg')
# (246, 'hara', '0000000482_0.jpg')
# (247, 'hara', '0000000483_0.jpg')
# (248, 'hara', '0000000484_0.jpg')
# (249, 'hara', '0000000485_0.jpg')
# (250, 'hara', '0000000486_0.jpg')
# (251, 'hara', '0000000487_0.jpg')
# (252, 'hara', '0000000488_0.jpg')
# (253, 'hara', '0000000489_0.jpg')
# (254, 'hara', '0000000490_0.jpg')
# (255, 'hara', '0000000491_0.jpg')
# (256, 'hara', '0000000492_0.jpg')
# (257, 'hara', '0000000493_0.jpg')
# (258, 'hara', '0000000494_0.jpg')
# (259, 'hara', '0000000495_0.jpg')
# (260, 'hara', '0000000496_0.jpg')
# (261, 'hara', '0000000497_0.jpg')
# (262, 'hara', '0000000498_0.jpg')
# (263, 'hara', '0000000499_0.jpg')
# (264, 'hara', '0000000500_0.jpg')
# (265, 'hara', '0000000501_0.jpg')
# (266, 'hara', '0000000502_0.jpg')
# (267, 'hara', '0000000503_0.jpg')
# (268, 'hara', '0000000504_0.jpg')
# (269, 'hara', '0000000505_0.jpg')
# (270, 'hara', '0000000506_0.jpg')
# (271, 'hara', '0000000507_0.jpg')
# (272, 'hara', '0000000508_0.jpg')
# (273, 'hara', '0000000509_0.jpg')
# (274, 'hara', '0000000510_0.jpg')
# (275, 'hara', '0000000511_0.jpg')
# (276, 'hara', '0000000512_0.jpg')
# (277, 'hara', '0000000513_0.jpg')
# (278, 'hara', '0000000514_0.jpg')
# (279, 'hara', '0000000515_0.jpg')
# (280, 'hara', '0000000516_0.jpg')
# (281, 'hara', '0000000517_0.jpg')
# (282, 'hara', '0000000518_0.jpg')
# (283, 'hara', '0000000519_0.jpg')
# (284, 'hara', '0000000520_0.jpg')
# (285, 'hara', '0000000521_0.jpg')
# (286, 'hara', '0000000522_0.jpg')
# (287, 'hara', '0000000523_0.jpg')
# (288, 'hara', '0000000524_0.jpg')
# (289, 'hara', '0000000525_0.jpg')
# (290, 'hara', '0000000526_0.jpg')
# (291, 'hara', '0000000527_0.jpg')
# (292, 'hara', '0000000528_0.jpg')
# (293, 'hara', '0000000529_0.jpg')
# (294, 'hara', '0000000530_0.jpg')
# (295, 'hara', '0000000531_0.jpg')
# (296, 'hara', '0000000532_0.jpg')
# (297, 'hara', '0000000533_0.jpg')
# (298, 'hara', '0000000534_0.jpg')
# (299, 'hara', '0000000535_0.jpg')
# (300, 'hara', '0000000536_0.jpg')
# (301, 'hara', '0000000537_0.jpg')
# (302, 'hara', '0000000538_0.jpg')
# (303, 'hara', '0000000539_0.jpg')
# (304, 'hara', '0000000540_0.jpg')
# (305, 'hara', '0000000541_0.jpg')
# (306, 'hara', '0000000542_0.jpg')
# (307, 'hara', '0000000543_0.jpg')
# (308, 'hara', '0000000544_0.jpg')
# (309, 'hara', '0000000545_0.jpg')
# (310, 'hara', '0000000546_0.jpg')
# (311, 'hara', '0000000547_0.jpg')
# (312, 'hara', '0000000548_0.jpg')
# (313, 'hara', '0000000549_0.jpg')
# (314, 'hara', '0000000550_0.jpg')
# (315, 'hara', '0000000551_0.jpg')
# (316, 'hara', '0000000552_0.jpg')
# (317, 'hara', '0000000553_0.jpg')
# (318, 'hara', '0000000554_0.jpg')
# (319, 'hara', '0000000555_0.jpg')
# (320, 'hara', '0000000556_0.jpg')
# (321, 'hara', '0000000557_0.jpg')
# (322, 'hara', '0000000558_0.jpg')
# (323, 'hara', '0000000559_0.jpg')
# (324, 'hara', '0000000560_0.jpg')
# (325, 'hara', '0000000561_0.jpg')
# (326, 'hara', '0000000562_0.jpg')
# (327, 'hara', '0000000563_0.jpg')
# (328, 'hara', '0000000564_0.jpg')
# (329, 'hara', '0000000565_0.jpg')
# (330, 'hara', '0000000566_0.jpg')
# (331, 'hara', '0000000567_0.jpg')
# (332, 'hara', '0000000568_0.jpg')
# (333, 'hara', '0000000569_0.jpg')
# (334, 'hara', '0000000570_0.jpg')
# (335, 'hara', '0000000571_0.jpg')
# (336, 'hara', '0000000572_0.jpg')
# (337, 'hara', '0000000573_0.jpg')
# (338, 'hara', '0000000574_0.jpg')
# (339, 'hara', '0000000575_0.jpg')
# (340, 'hara', '0000000576_0.jpg')
# (341, 'hara', '0000000577_0.jpg')
# (342, 'hara', '0000000578_0.jpg')
# (343, 'hara', '0000000579_0.jpg')
# (344, 'hara', '0000000580_0.jpg')
# (345, 'hara', '0000000581_0.jpg')
# (346, 'hara', '0000000582_0.jpg')
# (347, 'hara', '0000000583_0.jpg')
# (348, 'hara', '0000000584_0.jpg')
# (349, 'hara', '0000000585_0.jpg')
# (350, 'hara', '0000000586_0.jpg')
# (351, 'hara', '0000000587_0.jpg')
# (352, 'hara', '0000000588_0.jpg')
# (353, 'hara', '0000000589_0.jpg')
# (354, 'hara', '0000000590_0.jpg')
# (355, 'hara', '0000000591_0.jpg')
# (356, 'hara', '0000000592_0.jpg')
# (357, 'hara', '0000000593_0.jpg')
# (358, 'hara', '0000000594_0.jpg')
# (359, 'hara', '0000000595_0.jpg')
# (360, 'hara', '0000000596_0.jpg')
# (361, 'hara', '0000000597_0.jpg')
# (362, 'hara', '0000000598_0.jpg')
# (363, 'hara', '0000000599_0.jpg')
# (364, 'hara', '0000000600_0.jpg')
# (365, 'hara', '0000000601_0.jpg')
# (366, 'hara', '0000000602_0.jpg')
# (367, 'hara', '0000000603_0.jpg')
# (368, 'hara', '0000000604_0.jpg')
# (369, 'hara', '0000000605_0.jpg')
# (370, 'hara', '0000000606_0.jpg')
# (371, 'hara', '0000000607_0.jpg')
# (372, 'hara', '0000000608_0.jpg')
# (373, 'hara', '0000000609_0.jpg')
# (374, 'hara', '0000000610_0.jpg')
# (375, 'hara', '0000000611_0.jpg')
# (376, 'hara', '0000000612_0.jpg')
# (377, 'hara', '0000000613_0.jpg')
# (378, 'hara', '0000000614_0.jpg')
# (379, 'hara', '0000000615_0.jpg')
# (380, 'hara', '0000000616_0.jpg')
# (381, 'hara', '0000000617_0.jpg')
# (382, 'hara', '0000000618_0.jpg')
# (383, 'hara', '0000000619_0.jpg')
# (384, 'hara', '0000000620_0.jpg')
# (385, 'hara', '0000000621_0.jpg')
# (386, 'hara', '0000000622_0.jpg')
# (387, 'hara', '0000000623_0.jpg')
# (388, 'hara', '0000000624_0.jpg')
# (389, 'hara', '0000000625_0.jpg')
# (390, 'hara', '0000000626_0.jpg')
# (391, 'hara', '0000000627_0.jpg')
# (392, 'hara', '0000000628_0.jpg')
# (393, 'hara', '0000000629_0.jpg')
# (394, 'hara', '0000000630_0.jpg')
# (395, 'hara', '0000000631_0.jpg')
# (396, 'hara', '0000000632_0.jpg')
# (397, 'hara', '0000000633_0.jpg')
# (398, 'hara', '0000000634_0.jpg')
# (399, 'hara', '0000000635_0.jpg')
# (400, 'hara', '0000000636_0.jpg')
# (401, 'hara', '0000000637_0.jpg')
# (402, 'hara', '0000000638_0.jpg')
# (403, 'hara', '0000000639_0.jpg')
# (404, 'hara', '0000000640_0.jpg')
# (405, 'hara', '0000000641_0.jpg')
# (406, 'hara', '0000000642_0.jpg')
# (407, 'hara', '0000000643_0.jpg')
# (408, 'hara', '0000000644_0.jpg')
# (409, 'hara', '0000000645_0.jpg')
# (410, 'hara', '0000000646_0.jpg')
# (411, 'hara', '0000000647_0.jpg')
# (412, 'hara', '0000000648_0.jpg')
# (413, 'hara', '0000000649_0.jpg')
# (414, 'hara', '0000000650_0.jpg')
# (415, 'hara', '0000000651_0.jpg')
# (416, 'hara', '0000000652_0.jpg')
# (417, 'hara', '0000000653_0.jpg')
# (418, 'hara', '0000000654_0.jpg')
# (419, 'hara', '0000000655_0.jpg')
# (420, 'hara', '0000000656_0.jpg')
# (421, 'hara', '0000000657_0.jpg')
# (422, 'hara', '0000000658_0.jpg')
# (423, 'hara', '0000000659_0.jpg')
# (424, 'hara', '0000000660_0.jpg')
# (425, 'hara', '0000000661_0.jpg')
# (426, 'hara', '0000000662_0.jpg')
# (427, 'hara', '0000000663_0.jpg')
# (428, 'hara', '0000000664_0.jpg')
# (429, 'hara', '0000000665_0.jpg')
# (430, 'hara', '0000000666_0.jpg')
# (431, 'hara', '0000000667_0.jpg')
# (432, 'hara', '0000000668_0.jpg')
# (433, 'hara', '0000000669_0.jpg')
# (434, 'hara', '0000000670_0.jpg')
# (435, 'hara', '0000000671_0.jpg')
# (436, 'hara', '0000000672_0.jpg')
# (437, 'hara', '0000000673_0.jpg')
# (438, 'hara', '0000000674_0.jpg')
# (439, 'hara', '0000000675_0.jpg')
# (440, 'hara', '0000000676_0.jpg')
# (441, 'hara', '0000000677_0.jpg')
# (442, 'hara', '0000000678_0.jpg')
# (443, 'hara', '0000000679_0.jpg')
# (444, 'hara', '0000000680_0.jpg')
# (445, 'hara', '0000000681_0.jpg')
# (446, 'hara', '0000000682_0.jpg')
# (447, 'hara', '0000000683_0.jpg')
# (448, 'hara', '0000000684_0.jpg')
# (449, 'hara', '0000000685_0.jpg')
# (450, 'hara', '0000000686_0.jpg')
# (451, 'hara', '0000000687_0.jpg')
# (452, 'hara', '0000000688_0.jpg')
# (453, 'hara', '0000000689_0.jpg')
# (454, 'hara', '0000000690_0.jpg')
# (455, 'hara', '0000000691_0.jpg')
# (456, 'hara', '0000000692_0.jpg')
# (457, 'hara', '0000000693_0.jpg')
# (458, 'hara', '0000000694_0.jpg')
# (459, 'hara', '0000000695_0.jpg')
# (460, 'hara', '0000000696_0.jpg')
# (461, 'hara', '0000000697_0.jpg')
# (462, 'hara', '0000000698_0.jpg')
# (463, 'hara', '0000000699_0.jpg')
# (464, 'hara', '0000000700_0.jpg')
# (465, 'hara', '0000000701_0.jpg')
# (466, 'hara', '0000000702_0.jpg')
# (467, 'hara', '0000000703_0.jpg')
# (468, 'hara', '0000000704_0.jpg')
# (469, 'hara', '0000000705_0.jpg')
# (470, 'hara', '0000000706_0.jpg')
# (471, 'hara', '0000000707_0.jpg')
# (472, 'hara', '0000000708_0.jpg')
# (473, 'hara', '0000000709_0.jpg')
# (474, 'hara', '0000000710_0.jpg')
# (475, 'hara', '0000000711_0.jpg')
# (476, 'hara', '0000000712_0.jpg')
# (477, 'hara', '0000000713_0.jpg')
# (478, 'hara', '0000000714_0.jpg')
# (479, 'hara', '0000000715_0.jpg')
# (480, 'hara', '0000000716_0.jpg')
# (481, 'hara', '0000000717_0.jpg')
# (482, 'hara', '0000000718_0.jpg')
# (483, 'hara', '0000000719_0.jpg')
# (484, 'hara', '0000000720_0.jpg')
# (485, 'hara', '0000000721_0.jpg')
# (486, 'hara', '0000000722_0.jpg')
# (487, 'hara', '0000000723_0.jpg')
# (488, 'hara', '0000000724_0.jpg')
# (489, 'hara', '0000000725_0.jpg')
# (490, 'hara', '0000000726_0.jpg')
# (491, 'hara', '0000000727_0.jpg')
# (492, 'hara', '0000000728_0.jpg')
# (493, 'hara', '0000000729_0.jpg')
# (494, 'hara', '0000000730_0.jpg')
# (495, 'hara', '0000000731_0.jpg')
# (496, 'hara', '0000000732_0.jpg')
# (497, 'hara', '0000000733_0.jpg')
# (498, 'hara', '0000000734_0.jpg')
# (499, 'hara', '0000000735_0.jpg')
# (500, 'hara', '0000000736_0.jpg')
# (501, 'hara', '0000000737_0.jpg')
# (502, 'hara', '0000000738_0.jpg')
# (503, 'hara', '0000000739_0.jpg')
# (504, 'hara', '0000000740_0.jpg')
# (505, 'hara', '0000000741_0.jpg')
# (506, 'hara', '0000000742_0.jpg')
# (507, 'hara', '0000000743_0.jpg')
# (508, 'hara', '0000000744_0.jpg')
# (509, 'hara', '0000000745_0.jpg')
# (510, 'hara', '0000000746_0.jpg')
# (511, 'hara', '0000000747_0.jpg')
# (512, 'hara', '0000000748_0.jpg')
# (513, 'hara', '0000000749_0.jpg')
# (514, 'hara', '0000000750_0.jpg')
# (515, 'hara', '0000000751_0.jpg')
# (516, 'hara', '0000000752_0.jpg')
# (517, 'hara', '0000000753_0.jpg')
# (518, 'hara', '0000000754_0.jpg')
# (519, 'hara', '0000000755_0.jpg')
# (520, 'hara', '0000000756_0.jpg')
# (521, 'hara', '0000000757_0.jpg')
# (522, 'hara', '0000000758_0.jpg')
# (523, 'hara', '0000000759_0.jpg')
# (524, 'hara', '0000000760_0.jpg')
# (525, 'hara', '0000000761_0.jpg')
# (526, 'hara', '0000000762_0.jpg')
# (527, 'hara', '0000000763_0.jpg')
# (528, 'hara', '0000000764_0.jpg')
# (529, 'hara', '0000000765_0.jpg')
# (530, 'hara', '0000000766_0.jpg')
# (531, 'hara', '0000000767_0.jpg')
# (532, 'hara', '0000000768_0.jpg')
# (533, 'hara', '0000000769_0.jpg')
# (534, 'hara', '0000000770_0.jpg')
# (535, 'hara', '0000000771_0.jpg')
# (536, 'hara', '0000000772_0.jpg')
# (537, 'hara', '0000000773_0.jpg')
# (538, 'hara', '0000000774_0.jpg')
# (539, 'hara', '0000000775_0.jpg')
# (540, 'hara', '0000000776_0.jpg')
# (541, 'hara', '0000000777_0.jpg')
# (542, 'hara', '0000000778_0.jpg')
# (543, 'hara', '0000000779_0.jpg')
# (544, 'hara', '0000000780_0.jpg')
# (545, 'hara', '0000000781_0.jpg')
# (546, 'hara', '0000000782_0.jpg')
# (547, 'hara', '0000000783_0.jpg')
# (548, 'hara', '0000000784_0.jpg')
# (549, 'hara', '0000000785_0.jpg')
# (550, 'hara', '0000000786_0.jpg')
# (551, 'hara', '0000000787_0.jpg')
# (552, 'hara', '0000000788_0.jpg')
# (553, 'hara', '0000000789_0.jpg')
# (554, 'hara', '0000000790_0.jpg')
# (555, 'hara', '0000000791_0.jpg')
# (556, 'hara', '0000000792_0.jpg')
# (557, 'hara', '0000000793_0.jpg')
# (558, 'hara', '0000000794_0.jpg')
# (559, 'hara', '0000000795_0.jpg')
# (560, 'hara', '0000000796_0.jpg')
# (561, 'hara', '0000000797_0.jpg')
# (562, 'hara', '0000000798_0.jpg')
# (563, 'hara', '0000000799_0.jpg')
# (564, 'hara', '0000000800_0.jpg')
# (565, 'hara', '0000000801_0.jpg')
# (566, 'hara', '0000000802_0.jpg')
# (567, 'hara', '0000000803_0.jpg')
# (568, 'hara', '0000000804_0.jpg')
# (569, 'hara', '0000000805_0.jpg')
# (570, 'hara', '0000000806_0.jpg')
# (571, 'hara', '0000000807_0.jpg')
# (572, 'hara', '0000000808_0.jpg')
# (573, 'hara', '0000000809_0.jpg')
# (574, 'hara', '0000000810_0.jpg')
# (575, 'hara', '0000000811_0.jpg')
# (576, 'hara', '0000000812_0.jpg')
# (577, 'hara', '0000000813_0.jpg')
# (578, 'hara', '0000000814_0.jpg')
# (579, 'hara', '0000000815_0.jpg')
# (580, 'hara', '0000000816_0.jpg')
# (581, 'hara', '0000000817_0.jpg')
# (582, 'hara', '0000000818_0.jpg')
# (583, 'hara', '0000000819_0.jpg')
# (584, 'hara', '0000000820_0.jpg')
# (585, 'hara', '0000000821_0.jpg')
# (586, 'hara', '0000000822_0.jpg')
# (587, 'hara', '0000000823_0.jpg')
# (588, 'hara', '0000000824_0.jpg')
# (589, 'hara', '0000000825_0.jpg')
# (590, 'hara', '0000000826_0.jpg')
# (591, 'hara', '0000000827_0.jpg')
# (592, 'hara', '0000000828_0.jpg')
# (593, 'hara', '0000000829_0.jpg')
# (594, 'hara', '0000000830_0.jpg')
# (595, 'hara', '0000000831_0.jpg')
# (596, 'hara', '0000000832_0.jpg')
# (597, 'hara', '0000000833_0.jpg')
# (598, 'hara', '0000000834_0.jpg')
# (599, 'hara', '0000000835_0.jpg')
# (600, 'hara', '0000000836_0.jpg')
# (601, 'hara', '0000000837_0.jpg')
# (602, 'hara', '0000000838_0.jpg')
# (603, 'hara', '0000000839_0.jpg')
# (604, 'hara', '0000000840_0.jpg')
# (605, 'hara', '0000000841_0.jpg')
# (606, 'hara', '0000000842_0.jpg')
# (607, 'hara', '0000000843_0.jpg')
# (608, 'hara', '0000000844_0.jpg')
# (609, 'hara', '0000000845_0.jpg')
# (610, 'hara', '0000000846_0.jpg')
# (611, 'hara', '0000000847_0.jpg')
# (612, 'hara', '0000000848_0.jpg')
# (613, 'hara', '0000001143_2.jpg')
# ---------------------------
# (0, 'nothara', '0000000198_0.jpg')
# (1, 'nothara', '0000000198_1.jpg')
# (2, 'nothara', '0000000198_10.jpg')
# (3, 'nothara', '0000000198_11.jpg')
# (4, 'nothara', '0000000198_12.jpg')
# (5, 'nothara', '0000000198_13.jpg')
# (6, 'nothara', '0000000198_14.jpg')
# (7, 'nothara', '0000000198_15.jpg')
# (8, 'nothara', '0000000198_16.jpg')
# (9, 'nothara', '0000000198_17.jpg')
# (10, 'nothara', '0000000198_18.jpg')
# (11, 'nothara', '0000000198_19.jpg')
# (12, 'nothara', '0000000198_2.jpg')
# (13, 'nothara', '0000000198_20.jpg')
# (14, 'nothara', '0000000198_21.jpg')
# (15, 'nothara', '0000000198_22.jpg')
# (16, 'nothara', '0000000198_23.jpg')
# (17, 'nothara', '0000000198_24.jpg')
# (18, 'nothara', '0000000198_25.jpg')
# (19, 'nothara', '0000000198_26.jpg')
# (20, 'nothara', '0000000198_27.jpg')
# (21, 'nothara', '0000000198_28.jpg')
# (22, 'nothara', '0000000198_29.jpg')
# (23, 'nothara', '0000000198_3.jpg')
# (24, 'nothara', '0000000198_30.jpg')
# (25, 'nothara', '0000000198_31.jpg')
# (26, 'nothara', '0000000198_32.jpg')
# (27, 'nothara', '0000000198_33.jpg')
# (28, 'nothara', '0000000198_4.jpg')
# (29, 'nothara', '0000000198_5.jpg')
# (30, 'nothara', '0000000198_6.jpg')
# (31, 'nothara', '0000000198_7.jpg')
# (32, 'nothara', '0000000198_8.jpg')
# (33, 'nothara', '0000000198_9.jpg')
# (34, 'nothara', '0000000199_0.jpg')
# (35, 'nothara', '0000000199_1.jpg')
# (36, 'nothara', '0000000199_10.jpg')
# (37, 'nothara', '0000000199_11.jpg')
# (38, 'nothara', '0000000199_12.jpg')
# (39, 'nothara', '0000000199_13.jpg')
# (40, 'nothara', '0000000199_14.jpg')
# (41, 'nothara', '0000000199_15.jpg')
# (42, 'nothara', '0000000199_16.jpg')
# (43, 'nothara', '0000000199_17.jpg')
# (44, 'nothara', '0000000199_18.jpg')
# (45, 'nothara', '0000000199_19.jpg')
# (46, 'nothara', '0000000199_2.jpg')
# (47, 'nothara', '0000000199_20.jpg')
# (48, 'nothara', '0000000199_21.jpg')
# (49, 'nothara', '0000000199_22.jpg')
# (50, 'nothara', '0000000199_23.jpg')
# (51, 'nothara', '0000000199_24.jpg')
# (52, 'nothara', '0000000199_25.jpg')
# (53, 'nothara', '0000000199_26.jpg')
# (54, 'nothara', '0000000199_27.jpg')
# (55, 'nothara', '0000000199_28.jpg')
# (56, 'nothara', '0000000199_29.jpg')
# (57, 'nothara', '0000000199_3.jpg')
# (58, 'nothara', '0000000199_30.jpg')
# (59, 'nothara', '0000000199_31.jpg')
# (60, 'nothara', '0000000199_32.jpg')
# (61, 'nothara', '0000000199_33.jpg')
# (62, 'nothara', '0000000199_4.jpg')
# (63, 'nothara', '0000000199_5.jpg')
# (64, 'nothara', '0000000199_6.jpg')
# (65, 'nothara', '0000000199_7.jpg')
# (66, 'nothara', '0000000199_8.jpg')
# (67, 'nothara', '0000000199_9.jpg')
# (68, 'nothara', '0000000200_0.jpg')
# (69, 'nothara', '0000000200_1.jpg')
# (70, 'nothara', '0000000200_10.jpg')
# (71, 'nothara', '0000000200_11.jpg')
# (72, 'nothara', '0000000200_12.jpg')
# (73, 'nothara', '0000000200_13.jpg')
# (74, 'nothara', '0000000200_14.jpg')
# (75, 'nothara', '0000000200_15.jpg')
# (76, 'nothara', '0000000200_16.jpg')
# (77, 'nothara', '0000000200_17.jpg')
# (78, 'nothara', '0000000200_18.jpg')
# (79, 'nothara', '0000000200_19.jpg')
# (80, 'nothara', '0000000200_2.jpg')
# (81, 'nothara', '0000000200_20.jpg')
# (82, 'nothara', '0000000200_21.jpg')
# (83, 'nothara', '0000000200_22.jpg')
# (84, 'nothara', '0000000200_23.jpg')
# (85, 'nothara', '0000000200_24.jpg')
# (86, 'nothara', '0000000200_25.jpg')
# (87, 'nothara', '0000000200_26.jpg')
# (88, 'nothara', '0000000200_27.jpg')
# (89, 'nothara', '0000000200_28.jpg')
# (90, 'nothara', '0000000200_29.jpg')
# (91, 'nothara', '0000000200_3.jpg')
# (92, 'nothara', '0000000200_30.jpg')
# (93, 'nothara', '0000000200_31.jpg')
# (94, 'nothara', '0000000200_32.jpg')
# (95, 'nothara', '0000000200_33.jpg')
# (96, 'nothara', '0000000200_4.jpg')
# (97, 'nothara', '0000000200_5.jpg')
# (98, 'nothara', '0000000200_6.jpg')
# (99, 'nothara', '0000000200_7.jpg')
# (100, 'nothara', '0000000200_8.jpg')
# (101, 'nothara', '0000000200_9.jpg')
# (102, 'nothara', '0000000201_0.jpg')
# (103, 'nothara', '0000000201_1.jpg')
# (104, 'nothara', '0000000201_10.jpg')
# (105, 'nothara', '0000000201_11.jpg')
# (106, 'nothara', '0000000201_12.jpg')
# (107, 'nothara', '0000000201_13.jpg')
# (108, 'nothara', '0000000201_14.jpg')
# (109, 'nothara', '0000000201_15.jpg')
# (110, 'nothara', '0000000201_16.jpg')
# (111, 'nothara', '0000000201_17.jpg')
# (112, 'nothara', '0000000201_18.jpg')
# (113, 'nothara', '0000000201_19.jpg')
# (114, 'nothara', '0000000201_2.jpg')
# (115, 'nothara', '0000000201_20.jpg')
# (116, 'nothara', '0000000201_21.jpg')
# (117, 'nothara', '0000000201_22.jpg')
# (118, 'nothara', '0000000201_23.jpg')
# (119, 'nothara', '0000000201_24.jpg')
# (120, 'nothara', '0000000201_25.jpg')
# (121, 'nothara', '0000000201_26.jpg')
# (122, 'nothara', '0000000201_27.jpg')
# (123, 'nothara', '0000000201_28.jpg')
# (124, 'nothara', '0000000201_29.jpg')
# (125, 'nothara', '0000000201_3.jpg')
# (126, 'nothara', '0000000201_30.jpg')
# (127, 'nothara', '0000000201_31.jpg')
# (128, 'nothara', '0000000201_32.jpg')
# (129, 'nothara', '0000000201_33.jpg')
# (130, 'nothara', '0000000201_4.jpg')
# (131, 'nothara', '0000000201_5.jpg')
# (132, 'nothara', '0000000201_6.jpg')
# (133, 'nothara', '0000000201_7.jpg')
# (134, 'nothara', '0000000201_8.jpg')
# (135, 'nothara', '0000000201_9.jpg')
# (136, 'nothara', '0000000203_0.jpg')
# (137, 'nothara', '0000000204_0.jpg')
# (138, 'nothara', '0000000205_0.jpg')
# (139, 'nothara', '0000000207_0.jpg')
# (140, 'nothara', '0000000208_0.jpg')
# (141, 'nothara', '0000000208_1.jpg')
# (142, 'nothara', '0000000210_0.jpg')
# (143, 'nothara', '0000000210_1.jpg')
# (144, 'nothara', '0000000210_2.jpg')
# (145, 'nothara', '0000000213_2.jpg')
# (146, 'nothara', '0000000213_3.jpg')
# (147, 'nothara', '0000000214_11.jpg')
# (148, 'nothara', '0000000214_12.jpg')
# (149, 'nothara', '0000000214_13.jpg')
# (150, 'nothara', '0000000214_14.jpg')
# (151, 'nothara', '0000000214_15.jpg')
# (152, 'nothara', '0000000214_16.jpg')
# (153, 'nothara', '0000000214_17.jpg')
# (154, 'nothara', '0000000214_18.jpg')
# (155, 'nothara', '0000000214_19.jpg')
# (156, 'nothara', '0000000214_2.jpg')
# (157, 'nothara', '0000000214_20.jpg')
# (158, 'nothara', '0000000214_21.jpg')
# (159, 'nothara', '0000000214_22.jpg')
# (160, 'nothara', '0000000214_23.jpg')
# (161, 'nothara', '0000000214_24.jpg')
# (162, 'nothara', '0000000214_25.jpg')
# (163, 'nothara', '0000000214_26.jpg')
# (164, 'nothara', '0000000214_27.jpg')
# (165, 'nothara', '0000000214_28.jpg')
# (166, 'nothara', '0000000214_3.jpg')
# (167, 'nothara', '0000000214_30.jpg')
# (168, 'nothara', '0000000214_31.jpg')
# (169, 'nothara', '0000000214_4.jpg')
# (170, 'nothara', '0000000214_5.jpg')
# (171, 'nothara', '0000000214_6.jpg')
# (172, 'nothara', '0000000214_7.jpg')
# (173, 'nothara', '0000000214_8.jpg')
# (174, 'nothara', '0000000214_9.jpg')
# (175, 'nothara', '0000000215_0.jpg')
# (176, 'nothara', '0000000215_1.jpg')
# (177, 'nothara', '0000000215_2.jpg')
# (178, 'nothara', '0000000215_3.jpg')
# (179, 'nothara', '0000000215_4.jpg')
# (180, 'nothara', '0000000215_5.jpg')
# (181, 'nothara', '0000000215_6.jpg')
# (182, 'nothara', '0000000215_7.jpg')
# (183, 'nothara', '0000000215_8.jpg')
# (184, 'nothara', '0000000215_9.jpg')
# (185, 'nothara', '0000000216_3.jpg')
# (186, 'nothara', '0000000216_4.jpg')
# (187, 'nothara', '0000000216_5.jpg')
# (188, 'nothara', '0000000219_0.jpg')
# (189, 'nothara', '0000000219_1.jpg')
# (190, 'nothara', '0000000219_2.jpg')
# (191, 'nothara', '0000000220_1.jpg')
# (192, 'nothara', '0000000220_2.jpg')
# (193, 'nothara', '0000000220_3.jpg')
# (194, 'nothara', '0000000227_0.jpg')
# (195, 'nothara', '0000000227_2.jpg')
# (196, 'nothara', '0000000849_0.jpg')
# (197, 'nothara', '0000000850_1.jpg')
# (198, 'nothara', '0000000851_1.jpg')
# (199, 'nothara', '0000000852_2.jpg')
# (200, 'nothara', '0000000853_1.jpg')
# (201, 'nothara', '0000000854_2.jpg')
# (202, 'nothara', '0000000855_0.jpg')
# (203, 'nothara', '0000000856_1.jpg')
# (204, 'nothara', '0000000857_0.jpg')
# (205, 'nothara', '0000000858_1.jpg')
# (206, 'nothara', '0000000859_0.jpg')
# (207, 'nothara', '0000000860_3.jpg')
# (208, 'nothara', '0000000861_2.jpg')
# (209, 'nothara', '0000000862_2.jpg')
# (210, 'nothara', '0000000863_2.jpg')
# (211, 'nothara', '0000000864_2.jpg')
# (212, 'nothara', '0000000865_0.jpg')
# (213, 'nothara', '0000000866_0.jpg')
# (214, 'nothara', '0000000867_0.jpg')
# (215, 'nothara', '0000000868_2.jpg')
# (216, 'nothara', '0000000869_0.jpg')
# (217, 'nothara', '0000000870_2.jpg')
# (218, 'nothara', '0000000871_1.jpg')
# (219, 'nothara', '0000000872_1.jpg')
# (220, 'nothara', '0000000873_1.jpg')
# (221, 'nothara', '0000000874_1.jpg')
# (222, 'nothara', '0000000875_0.jpg')
# (223, 'nothara', '0000000876_2.jpg')
# (224, 'nothara', '0000000877_1.jpg')
# (225, 'nothara', '0000000878_1.jpg')
# (226, 'nothara', '0000000879_2.jpg')
# (227, 'nothara', '0000000880_1.jpg')
# (228, 'nothara', '0000000881_2.jpg')
# (229, 'nothara', '0000000882_0.jpg')
# (230, 'nothara', '0000000883_0.jpg')
# (231, 'nothara', '0000000884_1.jpg')
# (232, 'nothara', '0000000885_0.jpg')
# (233, 'nothara', '0000000886_0.jpg')
# (234, 'nothara', '0000000887_0.jpg')
# (235, 'nothara', '0000000888_0.jpg')
# (236, 'nothara', '0000000889_0.jpg')
# (237, 'nothara', '0000000890_0.jpg')
# (238, 'nothara', '0000000891_0.jpg')
# (239, 'nothara', '0000000892_0.jpg')
# (240, 'nothara', '0000000893_0.jpg')
# (241, 'nothara', '0000000894_0.jpg')
# (242, 'nothara', '0000000895_0.jpg')
# (243, 'nothara', '0000000896_0.jpg')
# (244, 'nothara', '0000000897_0.jpg')
# (245, 'nothara', '0000000898_0.jpg')
# (246, 'nothara', '0000000899_0.jpg')
# (247, 'nothara', '0000000900_1.jpg')
# (248, 'nothara', '0000000901_0.jpg')
# (249, 'nothara', '0000000902_0.jpg')
# (250, 'nothara', '0000000903_0.jpg')
# (251, 'nothara', '0000000904_0.jpg')
# (252, 'nothara', '0000000905_0.jpg')
# (253, 'nothara', '0000000906_0.jpg')
# (254, 'nothara', '0000000907_0.jpg')
# (255, 'nothara', '0000000908_0.jpg')
# (256, 'nothara', '0000000909_0.jpg')
# (257, 'nothara', '0000000910_0.jpg')
# (258, 'nothara', '0000000911_1.jpg')
# (259, 'nothara', '0000000912_0.jpg')
# (260, 'nothara', '0000000913_0.jpg')
# (261, 'nothara', '0000000914_0.jpg')
# (262, 'nothara', '0000000915_0.jpg')
# (263, 'nothara', '0000000916_2.jpg')
# (264, 'nothara', '0000000917_1.jpg')
# (265, 'nothara', '0000000918_1.jpg')
# (266, 'nothara', '0000000919_1.jpg')
# (267, 'nothara', '0000000920_1.jpg')
# (268, 'nothara', '0000000921_2.jpg')
# (269, 'nothara', '0000000922_2.jpg')
# (270, 'nothara', '0000000923_2.jpg')
# (271, 'nothara', '0000000924_1.jpg')
# (272, 'nothara', '0000000925_1.jpg')
# (273, 'nothara', '0000000926_1.jpg')
# (274, 'nothara', '0000000927_2.jpg')
# (275, 'nothara', '0000000928_0.jpg')
# (276, 'nothara', '0000000929_4.jpg')
# (277, 'nothara', '0000000930_2.jpg')
# (278, 'nothara', '0000000931_0.jpg')
# (279, 'nothara', '0000000932_0.jpg')
# (280, 'nothara', '0000000932_2.jpg')
# (281, 'nothara', '0000000933_1.jpg')
# (282, 'nothara', '0000000933_2.jpg')
# (283, 'nothara', '0000000934_0.jpg')
# (284, 'nothara', '0000000934_1.jpg')
# (285, 'nothara', '0000000935_1.jpg')
# (286, 'nothara', '0000000935_3.jpg')
# (287, 'nothara', '0000000936_2.jpg')
# (288, 'nothara', '0000000936_3.jpg')
# (289, 'nothara', '0000000937_1.jpg')
# (290, 'nothara', '0000000937_2.jpg')
# (291, 'nothara', '0000000938_1.jpg')
# (292, 'nothara', '0000000938_2.jpg')
# (293, 'nothara', '0000000939_2.jpg')
# (294, 'nothara', '0000000939_3.jpg')
# (295, 'nothara', '0000000940_0.jpg')
# (296, 'nothara', '0000000940_1.jpg')
# (297, 'nothara', '0000000941_0.jpg')
# (298, 'nothara', '0000000941_1.jpg')
# (299, 'nothara', '0000000942_0.jpg')
# (300, 'nothara', '0000000942_1.jpg')
# (301, 'nothara', '0000000943_0.jpg')
# (302, 'nothara', '0000000943_1.jpg')
# (303, 'nothara', '0000000944_1.jpg')
# (304, 'nothara', '0000000944_2.jpg')
# (305, 'nothara', '0000000945_1.jpg')
# (306, 'nothara', '0000000945_2.jpg')
# (307, 'nothara', '0000000946_0.jpg')
# (308, 'nothara', '0000000947_0.jpg')
# (309, 'nothara', '0000000948_0.jpg')
# (310, 'nothara', '0000000949_1.jpg')
# (311, 'nothara', '0000000950_1.jpg')
# (312, 'nothara', '0000000951_1.jpg')
# (313, 'nothara', '0000000952_0.jpg')
# (314, 'nothara', '0000000953_0.jpg')
# (315, 'nothara', '0000000954_0.jpg')
# (316, 'nothara', '0000000955_0.jpg')
# (317, 'nothara', '0000000956_1.jpg')
# (318, 'nothara', '0000000957_0.jpg')
# (319, 'nothara', '0000000958_0.jpg')
# (320, 'nothara', '0000000959_0.jpg')
# (321, 'nothara', '0000000960_0.jpg')
# (322, 'nothara', '0000000961_0.jpg')
# (323, 'nothara', '0000000962_0.jpg')
# (324, 'nothara', '0000000963_0.jpg')
# (325, 'nothara', '0000000964_0.jpg')
# (326, 'nothara', '0000000965_0.jpg')
# (327, 'nothara', '0000000966_0.jpg')
# (328, 'nothara', '0000000967_0.jpg')
# (329, 'nothara', '0000000968_0.jpg')
# (330, 'nothara', '0000000969_1.jpg')
# (331, 'nothara', '0000000970_0.jpg')
# (332, 'nothara', '0000000971_1.jpg')
# (333, 'nothara', '0000000972_0.jpg')
# (334, 'nothara', '0000000973_0.jpg')
# (335, 'nothara', '0000000974_0.jpg')
# (336, 'nothara', '0000000975_1.jpg')
# (337, 'nothara', '0000000976_0.jpg')
# (338, 'nothara', '0000000977_1.jpg')
# (339, 'nothara', '0000000978_0.jpg')
# (340, 'nothara', '0000000979_0.jpg')
# (341, 'nothara', '0000000980_0.jpg')
# (342, 'nothara', '0000000981_0.jpg')
# (343, 'nothara', '0000000982_0.jpg')
# (344, 'nothara', '0000000983_0.jpg')
# (345, 'nothara', '0000000984_0.jpg')
# (346, 'nothara', '0000000985_0.jpg')
# (347, 'nothara', '0000000986_0.jpg')
# (348, 'nothara', '0000000987_0.jpg')
# (349, 'nothara', '0000000988_0.jpg')
# (350, 'nothara', '0000000989_1.jpg')
# (351, 'nothara', '0000000990_2.jpg')
# (352, 'nothara', '0000000991_0.jpg')
# (353, 'nothara', '0000000992_0.jpg')
# (354, 'nothara', '0000000993_0.jpg')
# (355, 'nothara', '0000000994_0.jpg')
# (356, 'nothara', '0000000995_0.jpg')
# (357, 'nothara', '0000000996_0.jpg')
# (358, 'nothara', '0000000997_1.jpg')
# (359, 'nothara', '0000000998_1.jpg')
# (360, 'nothara', '0000000999_0.jpg')
# (361, 'nothara', '0000001009_0.jpg')
# (362, 'nothara', '0000001010_0.jpg')
# (363, 'nothara', '0000001010_1.jpg')
# (364, 'nothara', '0000001014_2.jpg')
# (365, 'nothara', '0000001020_0.jpg')
# (366, 'nothara', '0000001021_1.jpg')
# (367, 'nothara', '0000001023_0.jpg')
# (368, 'nothara', '0000001023_2.jpg')
# (369, 'nothara', '0000001024_0.jpg')
# (370, 'nothara', '0000001024_2.jpg')
# (371, 'nothara', '0000001025_1.jpg')
# (372, 'nothara', '0000001026_1.jpg')
# (373, 'nothara', '0000001027_0.jpg')
# (374, 'nothara', '0000001027_1.jpg')
# (375, 'nothara', '0000001028_0.jpg')
# (376, 'nothara', '0000001029_0.jpg')
# (377, 'nothara', '0000001030_0.jpg')
# (378, 'nothara', '0000001031_0.jpg')
# (379, 'nothara', '0000001032_0.jpg')
# (380, 'nothara', '0000001033_0.jpg')
# (381, 'nothara', '0000001034_0.jpg')
# (382, 'nothara', '0000001035_0.jpg')
# (383, 'nothara', '0000001036_0.jpg')
# (384, 'nothara', '0000001037_0.jpg')
# (385, 'nothara', '0000001038_0.jpg')
# (386, 'nothara', '0000001039_0.jpg')
# (387, 'nothara', '0000001040_0.jpg')
# (388, 'nothara', '0000001041_0.jpg')
# (389, 'nothara', '0000001042_0.jpg')
# (390, 'nothara', '0000001043_0.jpg')
# (391, 'nothara', '0000001044_0.jpg')
# (392, 'nothara', '0000001045_0.jpg')
# (393, 'nothara', '0000001046_0.jpg')
# (394, 'nothara', '0000001047_0.jpg')
# (395, 'nothara', '0000001048_0.jpg')
# (396, 'nothara', '0000001049_0.jpg')
# (397, 'nothara', '0000001050_0.jpg')
# (398, 'nothara', '0000001051_0.jpg')
# (399, 'nothara', '0000001052_0.jpg')
# (400, 'nothara', '0000001053_0.jpg')
# (401, 'nothara', '0000001054_1.jpg')
# (402, 'nothara', '0000001055_0.jpg')
# (403, 'nothara', '0000001056_1.jpg')
# (404, 'nothara', '0000001057_0.jpg')
# (405, 'nothara', '0000001058_0.jpg')
# (406, 'nothara', '0000001059_0.jpg')
# (407, 'nothara', '0000001060_0.jpg')
# (408, 'nothara', '0000001061_0.jpg')
# (409, 'nothara', '0000001062_0.jpg')
# (410, 'nothara', '0000001063_0.jpg')
# (411, 'nothara', '0000001064_0.jpg')
# (412, 'nothara', '0000001065_0.jpg')
# (413, 'nothara', '0000001066_0.jpg')
# (414, 'nothara', '0000001067_0.jpg')
# (415, 'nothara', '0000001068_0.jpg')
# (416, 'nothara', '0000001069_0.jpg')
# (417, 'nothara', '0000001070_0.jpg')
# (418, 'nothara', '0000001071_0.jpg')
# (419, 'nothara', '0000001072_0.jpg')
# (420, 'nothara', '0000001073_0.jpg')
# (421, 'nothara', '0000001074_0.jpg')
# (422, 'nothara', '0000001075_0.jpg')
# (423, 'nothara', '0000001076_0.jpg')
# (424, 'nothara', '0000001077_0.jpg')
# (425, 'nothara', '0000001078_0.jpg')
# (426, 'nothara', '0000001079_0.jpg')
# (427, 'nothara', '0000001080_0.jpg')
# (428, 'nothara', '0000001081_0.jpg')
# (429, 'nothara', '0000001082_0.jpg')
# (430, 'nothara', '0000001083_0.jpg')
# (431, 'nothara', '0000001084_0.jpg')
# (432, 'nothara', '0000001085_0.jpg')
# (433, 'nothara', '0000001086_0.jpg')
# (434, 'nothara', '0000001087_0.jpg')
# (435, 'nothara', '0000001088_0.jpg')
# (436, 'nothara', '0000001089_0.jpg')
# (437, 'nothara', '0000001090_0.jpg')
# (438, 'nothara', '0000001091_0.jpg')
# (439, 'nothara', '0000001092_0.jpg')
# (440, 'nothara', '0000001093_0.jpg')
# (441, 'nothara', '0000001094_0.jpg')
# (442, 'nothara', '0000001095_0.jpg')
# (443, 'nothara', '0000001096_0.jpg')
# (444, 'nothara', '0000001104_0.jpg')
# (445, 'nothara', '0000001105_0.jpg')
# (446, 'nothara', '0000001106_0.jpg')
# (447, 'nothara', '0000001107_0.jpg')
# (448, 'nothara', '0000001108_0.jpg')
# (449, 'nothara', '0000001109_1.jpg')
# (450, 'nothara', '0000001110_0.jpg')
# (451, 'nothara', '0000001111_0.jpg')
# (452, 'nothara', '0000001112_0.jpg')
# (453, 'nothara', '0000001113_1.jpg')
# (454, 'nothara', '0000001114_1.jpg')
# (455, 'nothara', '0000001115_0.jpg')
# (456, 'nothara', '0000001116_0.jpg')
# (457, 'nothara', '0000001117_1.jpg')
# (458, 'nothara', '0000001118_1.jpg')
# (459, 'nothara', '0000001119_0.jpg')
# (460, 'nothara', '0000001120_0.jpg')
# (461, 'nothara', '0000001121_0.jpg')
# (462, 'nothara', '0000001122_0.jpg')
# (463, 'nothara', '0000001123_0.jpg')
# (464, 'nothara', '0000001124_0.jpg')
# (465, 'nothara', '0000001125_0.jpg')
# (466, 'nothara', '0000001126_0.jpg')
# (467, 'nothara', '0000001127_0.jpg')
# (468, 'nothara', '0000001128_0.jpg')
# (469, 'nothara', '0000001129_0.jpg')
# (470, 'nothara', '0000001134_0.jpg')
# (471, 'nothara', '0000001135_1.jpg')
# (472, 'nothara', '0000001135_2.jpg')
# (473, 'nothara', '0000001140_0.jpg')
# (474, 'nothara', '0000001141_0.jpg')
# (475, 'nothara', '0000001142_0.jpg')
# (476, 'nothara', '0000001143_0.jpg')
# (477, 'nothara', '0000001143_1.jpg')
# (478, 'nothara', '0000001145_4.jpg')
# (479, 'nothara', '0000001145_5.jpg')
# (480, 'nothara', '0000001145_6.jpg')
# (481, 'nothara', '0000001146_2.jpg')
# (482, 'nothara', '0000001147_1.jpg')
# (483, 'nothara', '0000001147_2.jpg')
# (484, 'nothara', '0000001147_7.jpg')
# (485, 'nothara', '0000001147_8.jpg')
# (486, 'nothara', '0000001147_9.jpg')
# (487, 'nothara', '0000001149_0.jpg')
# (488, 'nothara', '0000001150_2.jpg')
# (489, 'nothara', '0000001150_3.jpg')
# (490, 'nothara', '0000001151_0.jpg')
# (491, 'nothara', '0000001151_1.jpg')
# (492, 'nothara', '0000001151_2.jpg')
# (493, 'nothara', '0000001151_3.jpg')
# (494, 'nothara', '0000001151_4.jpg')
# (495, 'nothara', '0000001151_5.jpg')
# (496, 'nothara', '0000001151_6.jpg')
# (497, 'nothara', '0000001151_7.jpg')
# (498, 'nothara', '0000001151_8.jpg')
# (499, 'nothara', '0000001151_9.jpg')
# (500, 'nothara', '0000001153_0.jpg')
# ---------------------------
# (0, 'nothuman', '0000000206_0.jpg')
# (1, 'nothuman', '0000000206_1.jpg')
# (2, 'nothuman', '0000000206_2.jpg')
# (3, 'nothuman', '0000000206_3.jpg')
# (4, 'nothuman', '0000000208_2.jpg')
# (5, 'nothuman', '0000000213_0.jpg')
# (6, 'nothuman', '0000000213_1.jpg')
# (7, 'nothuman', '0000000213_4.jpg')
# (8, 'nothuman', '0000000214_0.jpg')
# (9, 'nothuman', '0000000214_1.jpg')
# (10, 'nothuman', '0000000214_10.jpg')
# (11, 'nothuman', '0000000214_29.jpg')
# (12, 'nothuman', '0000000214_32.jpg')
# (13, 'nothuman', '0000000214_33.jpg')
# (14, 'nothuman', '0000000216_0.jpg')
# (15, 'nothuman', '0000000216_1.jpg')
# (16, 'nothuman', '0000000216_2.jpg')
# (17, 'nothuman', '0000000218_0.jpg')
# (18, 'nothuman', '0000000220_0.jpg')
# (19, 'nothuman', '0000000227_1.jpg')
# (20, 'nothuman', '0000000850_0.jpg')
# (21, 'nothuman', '0000000851_0.jpg')
# (22, 'nothuman', '0000000852_0.jpg')
# (23, 'nothuman', '0000000852_1.jpg')
# (24, 'nothuman', '0000000853_0.jpg')
# (25, 'nothuman', '0000000854_0.jpg')
# (26, 'nothuman', '0000000854_1.jpg')
# (27, 'nothuman', '0000000856_0.jpg')
# (28, 'nothuman', '0000000858_0.jpg')
# (29, 'nothuman', '0000000860_0.jpg')
# (30, 'nothuman', '0000000860_1.jpg')
# (31, 'nothuman', '0000000860_2.jpg')
# (32, 'nothuman', '0000000861_0.jpg')
# (33, 'nothuman', '0000000861_1.jpg')
# (34, 'nothuman', '0000000862_0.jpg')
# (35, 'nothuman', '0000000862_1.jpg')
# (36, 'nothuman', '0000000863_0.jpg')
# (37, 'nothuman', '0000000863_1.jpg')
# (38, 'nothuman', '0000000864_0.jpg')
# (39, 'nothuman', '0000000864_1.jpg')
# (40, 'nothuman', '0000000868_0.jpg')
# (41, 'nothuman', '0000000868_1.jpg')
# (42, 'nothuman', '0000000870_0.jpg')
# (43, 'nothuman', '0000000870_1.jpg')
# (44, 'nothuman', '0000000871_0.jpg')
# (45, 'nothuman', '0000000872_0.jpg')
# (46, 'nothuman', '0000000873_0.jpg')
# (47, 'nothuman', '0000000874_0.jpg')
# (48, 'nothuman', '0000000876_0.jpg')
# (49, 'nothuman', '0000000876_1.jpg')
# (50, 'nothuman', '0000000877_0.jpg')
# (51, 'nothuman', '0000000878_0.jpg')
# (52, 'nothuman', '0000000879_0.jpg')
# (53, 'nothuman', '0000000879_1.jpg')
# (54, 'nothuman', '0000000880_0.jpg')
# (55, 'nothuman', '0000000881_0.jpg')
# (56, 'nothuman', '0000000881_1.jpg')
# (57, 'nothuman', '0000000884_0.jpg')
# (58, 'nothuman', '0000000900_0.jpg')
# (59, 'nothuman', '0000000911_0.jpg')
# (60, 'nothuman', '0000000916_0.jpg')
# (61, 'nothuman', '0000000916_1.jpg')
# (62, 'nothuman', '0000000917_0.jpg')
# (63, 'nothuman', '0000000918_0.jpg')
# (64, 'nothuman', '0000000919_0.jpg')
# (65, 'nothuman', '0000000920_0.jpg')
# (66, 'nothuman', '0000000921_0.jpg')
# (67, 'nothuman', '0000000921_1.jpg')
# (68, 'nothuman', '0000000922_0.jpg')
# (69, 'nothuman', '0000000922_1.jpg')
# (70, 'nothuman', '0000000923_0.jpg')
# (71, 'nothuman', '0000000923_1.jpg')
# (72, 'nothuman', '0000000924_0.jpg')
# (73, 'nothuman', '0000000925_0.jpg')
# (74, 'nothuman', '0000000926_0.jpg')
# (75, 'nothuman', '0000000927_0.jpg')
# (76, 'nothuman', '0000000927_1.jpg')
# (77, 'nothuman', '0000000929_0.jpg')
# (78, 'nothuman', '0000000929_1.jpg')
# (79, 'nothuman', '0000000929_2.jpg')
# (80, 'nothuman', '0000000929_3.jpg')
# (81, 'nothuman', '0000000930_0.jpg')
# (82, 'nothuman', '0000000930_1.jpg')
# (83, 'nothuman', '0000000932_1.jpg')
# (84, 'nothuman', '0000000933_0.jpg')
# (85, 'nothuman', '0000000935_0.jpg')
# (86, 'nothuman', '0000000935_2.jpg')
# (87, 'nothuman', '0000000936_0.jpg')
# (88, 'nothuman', '0000000936_1.jpg')
# (89, 'nothuman', '0000000937_0.jpg')
# (90, 'nothuman', '0000000938_0.jpg')
# (91, 'nothuman', '0000000939_0.jpg')
# (92, 'nothuman', '0000000939_1.jpg')
# (93, 'nothuman', '0000000944_0.jpg')
# (94, 'nothuman', '0000000945_0.jpg')
# (95, 'nothuman', '0000000949_0.jpg')
# (96, 'nothuman', '0000000950_0.jpg')
# (97, 'nothuman', '0000000951_0.jpg')
# (98, 'nothuman', '0000000956_0.jpg')
# (99, 'nothuman', '0000000969_0.jpg')
# (100, 'nothuman', '0000000971_0.jpg')
# (101, 'nothuman', '0000000975_0.jpg')
# (102, 'nothuman', '0000000977_0.jpg')
# (103, 'nothuman', '0000000989_0.jpg')
# (104, 'nothuman', '0000000990_0.jpg')
# (105, 'nothuman', '0000000990_1.jpg')
# (106, 'nothuman', '0000000997_0.jpg')
# (107, 'nothuman', '0000000998_0.jpg')
# (108, 'nothuman', '0000001003_0.jpg')
# (109, 'nothuman', '0000001006_0.jpg')
# (110, 'nothuman', '0000001011_0.jpg')
# (111, 'nothuman', '0000001012_0.jpg')
# (112, 'nothuman', '0000001014_0.jpg')
# (113, 'nothuman', '0000001014_1.jpg')
# (114, 'nothuman', '0000001019_0.jpg')
# (115, 'nothuman', '0000001021_0.jpg')
# (116, 'nothuman', '0000001023_1.jpg')
# (117, 'nothuman', '0000001024_1.jpg')
# (118, 'nothuman', '0000001025_0.jpg')
# (119, 'nothuman', '0000001026_0.jpg')
# (120, 'nothuman', '0000001028_1.jpg')
# (121, 'nothuman', '0000001030_1.jpg')
# (122, 'nothuman', '0000001054_0.jpg')
# (123, 'nothuman', '0000001056_0.jpg')
# (124, 'nothuman', '0000001109_0.jpg')
# (125, 'nothuman', '0000001113_0.jpg')
# (126, 'nothuman', '0000001114_0.jpg')
# (127, 'nothuman', '0000001117_0.jpg')
# (128, 'nothuman', '0000001118_0.jpg')
# (129, 'nothuman', '0000001135_0.jpg')
# (130, 'nothuman', '0000001145_0.jpg')
# (131, 'nothuman', '0000001145_1.jpg')
# (132, 'nothuman', '0000001145_2.jpg')
# (133, 'nothuman', '0000001145_3.jpg')
# (134, 'nothuman', '0000001146_0.jpg')
# (135, 'nothuman', '0000001146_1.jpg')
# (136, 'nothuman', '0000001147_0.jpg')
# (137, 'nothuman', '0000001147_3.jpg')
# (138, 'nothuman', '0000001147_4.jpg')
# (139, 'nothuman', '0000001147_5.jpg')
# (140, 'nothuman', '0000001147_6.jpg')
# (141, 'nothuman', '0000001150_0.jpg')
# (142, 'nothuman', '0000001150_1.jpg')
# ---------------------------
# complete!
